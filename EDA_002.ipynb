# %%
import warnings
warnings.simplefilter('ignore')

import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns


import plotly.express as px
from scipy import stats

# %%
df_1 = pd.read_csv('Bengaluru_Cleaned.csv')
df_2 = pd.read_csv('Chennai_Cleaned.csv')
df_3 = pd.read_csv('Delhi_Cleaned.csv')
df_4 = pd.read_csv('Kolkata_Cleaned.csv')
df_5 = pd.read_csv('Mumbai_Cleaned.csv')

# %%
y_1 = []

for i in df_1['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_1.append(i)
    
    
y_2 = []

for i in df_2['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_2.append(i)
    
y_3 = []

for i in df_3['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_3.append(i)

y_4 = []

for i in df_4['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_4.append(i)
    
y_5 = []

for i in df_5['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_5.append(i)

# %%
df_1['posted_date'] = y_1
df_2['posted_date'] = y_2
df_3['posted_date'] = y_3
df_4['posted_date'] = y_4
df_5['posted_date'] = y_5

# %%
df_1['posted_date'] = pd.to_datetime(df_1['posted_date'])
df_2['posted_date'] = pd.to_datetime(df_2['posted_date'])
df_3['posted_date'] = pd.to_datetime(df_3['posted_date'])
df_4['posted_date'] = pd.to_datetime(df_4['posted_date'])
df_5['posted_date'] = pd.to_datetime(df_5['posted_date'])

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_5,label='Mumbai',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
df_1 = df_1.sort_values(by=['posted_date'])
df_2 = df_2.sort_values(by=['posted_date'])
df_3 = df_3.sort_values(by=['posted_date'])
df_4 = df_4.sort_values(by=['posted_date'])
df_5 = df_5.sort_values(by=['posted_date'])

# %%
df_1['index1'] = df_1.index
df_2['index1'] = df_2.index
df_3['index1'] = df_3.index
df_4['index1'] = df_4.index
df_5['index1'] = df_5.index

# %%
slope_1, intercept_1, r_value_1, p_value_1, std_err_1 = stats.linregress(df_1['Rate'],df_1['index1'])
print("Slope is",slope_1) 
print("intercept is" , intercept_1)
# Out:
# Slope is 0.15294224224895014
# intercept is 10458.023194343963

# %%
slope_2, intercept_2, r_value_2, p_value_2, std_err_2 = stats.linregress(df_2['Rate'],df_2['index1'])
print("Slope is",slope_2) 
print("intercept is" , intercept_2)
# Out:
# Slope is -0.06638430860312505
# intercept is 8347.359157178193

# %%
slope_3, intercept_3, r_value_3, p_value_3, std_err_3 = stats.linregress(df_3['Rate'],df_3['index1'])
print("Slope is",slope_3) 
print("intercept is" , intercept_3)
# Out:
# Slope is 0.08038430400149933
# intercept is 8302.912195614705

# %%
slope_4, intercept_4, r_value_4, p_value_4, std_err_4 = stats.linregress(df_4['Rate'],df_4['index1'])
print("Slope is",slope_4) 
print("intercept is" , intercept_4)
# Out:
# Slope is 0.14563304570306282
# intercept is 9644.174050682177

# %%
slope_5, intercept_5, r_value_5, p_value_5, std_err_5 = stats.linregress(df_5['Rate'],df_5['index1'])
print("Slope is",slope_5) 
print("intercept is" , intercept_5)
# Out:
# Slope is 0.00590374539841444
# intercept is 6310.402925597708

# %%
df_6 = pd.read_csv('Nashik_Cleaned.csv')
df_7 = pd.read_csv('Raipur_Cleaned.csv')
df_8 = pd.read_csv('Bhubaneswar_Cleaned.csv')
df_9 = pd.read_csv('lucknow_Cleaned.csv')
df_10 = pd.read_csv('Jaipur_Cleaned.csv')
df_11 = pd.read_csv('Indore_Cleaned.csv')
df_12 = pd.read_csv('Kanpur_clean.csv')
df_13 = pd.read_csv('Surat_Cleaned.csv')
df_14 = pd.read_csv('Visakhapatnam_Cleaned.csv')
df_15 = pd.read_csv('Goa_Cleaned.csv')

# %%
y_6 = []

for i in df_6['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_6.append(i)
    
    
y_7 = []

for i in df_7['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_7.append(i)
    
y_8 = []

for i in df_8['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_8.append(i)

y_9 = []

for i in df_9['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_9.append(i)
    
y_10 = []

for i in df_10['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_10.append(i)
    
    
y_11 = []

for i in df_11['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_11.append(i)
    
    
y_12 = []

for i in df_12['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_12.append(i)
    
    
    
y_13 = []

for i in df_13['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_13.append(i)
    
    
    
y_14 = []

for i in df_14['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_14.append(i)
    
    
    
y_15 = []

for i in df_15['posted_date']:
    if i == 'December 2019':
        i = 'January 2020'
    y_15.append(i)

# %%
df_6['posted_date'] = y_6
df_7['posted_date'] = y_7
df_8['posted_date'] = y_8
df_9['posted_date'] = y_9
df_10['posted_date'] = y_10
df_11['posted_date'] = y_11
df_12['posted_date'] = y_12
df_13['posted_date'] = y_13
df_14['posted_date'] = y_14
df_15['posted_date'] = y_15

# %%
df_6['posted_date'] = pd.to_datetime(df_6['posted_date'])
df_7['posted_date'] = pd.to_datetime(df_7['posted_date'])
df_8['posted_date'] = pd.to_datetime(df_8['posted_date'])
df_9['posted_date'] = pd.to_datetime(df_9['posted_date'])
df_10['posted_date'] = pd.to_datetime(df_10['posted_date'])
df_11['posted_date'] = pd.to_datetime(df_11['posted_date'])
df_12['posted_date'] = pd.to_datetime(df_12['posted_date'])
df_13['posted_date'] = pd.to_datetime(df_13['posted_date'])
df_14['posted_date'] = pd.to_datetime(df_14['posted_date'])
df_15['posted_date'] = pd.to_datetime(df_15['posted_date'])

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
df_6 = df_6.sort_values(by=['posted_date'])
df_7 = df_7.sort_values(by=['posted_date'])
df_8 = df_8.sort_values(by=['posted_date'])
df_9 = df_9.sort_values(by=['posted_date'])
df_10 = df_10.sort_values(by=['posted_date'])
df_11 = df_11.sort_values(by=['posted_date'])
df_12 = df_12.sort_values(by=['posted_date'])
df_13 = df_13.sort_values(by=['posted_date'])
df_14 = df_14.sort_values(by=['posted_date'])
df_15 = df_15.sort_values(by=['posted_date'])

# %%
df_6['index1'] = df_6.index
df_7['index1'] = df_7.index
df_8['index1'] = df_8.index
df_9['index1'] = df_9.index
df_10['index1'] = df_10.index
df_11['index1'] = df_11.index
df_12['index1'] = df_12.index
df_13['index1'] = df_13.index
df_14['index1'] = df_14.index
df_15['index1'] = df_15.index

# %%
slope_6, intercept_6, r_value_6, p_value_6, std_err_6 = stats.linregress(df_6['Rate'],df_6['index1'])
print("Slope is",slope_6) 
print("intercept is" , intercept_6)
# Out:
# Slope is -0.0036336135447251755
# intercept is 280.364800977071

# %%
slope_7, intercept_7, r_value_7, p_value_7, std_err_7 = stats.linregress(df_7['Rate'],df_7['index1'])
print("Slope is",slope_7) 
print("intercept is" , intercept_7)
# Out:
# Slope is 0.015715933086273094
# intercept is 553.4510279067731

# %%
slope_8, intercept_8, r_value_8, p_value_8, std_err_8 = stats.linregress(df_8['Rate'],df_8['index1'])
print("Slope is",slope_8) 
print("intercept is" , intercept_8)
# Out:
# Slope is -0.015936964494533638
# intercept is 474.6054770456337

# %%
slope_9, intercept_9, r_value_9, p_value_9, std_err_9 = stats.linregress(df_9['Rate'],df_9['index1'])
print("Slope is",slope_9) 
print("intercept is" , intercept_9)
# Out:
# Slope is -0.004774668141280065
# intercept is 496.20669252392764

# %%
slope_10, intercept_10, r_value_10, p_value_10, std_err_10 = stats.linregress(df_10['Rate'],df_10['index1'])
print("Slope is",slope_10) 
print("intercept is" , intercept_10)
# Out:
# Slope is 0.022030153105310174
# intercept is 923.5759138392012

# %%
slope_11, intercept_11, r_value_11, p_value_11, std_err_11 = stats.linregress(df_11['Rate'],df_11['index1'])
print("Slope is",slope_11) 
print("intercept is" , intercept_11)
# Out:
# Slope is -0.006775726319834402
# intercept is 594.8478335928916

# %%
slope_12, intercept_12, r_value_12, p_value_12, std_err_12 = stats.linregress(df_12['Rate'],df_12['index1'])
print("Slope is",slope_12) 
print("intercept is" , intercept_12)
# Out:
# Slope is -0.04792503861965286
# intercept is 741.301080679919

# %%
slope_13, intercept_13, r_value_13, p_value_13, std_err_13 = stats.linregress(df_13['Rate'],df_13['index1'])
print("Slope is",slope_13) 
print("intercept is" , intercept_13)
# Out:
# Slope is 0.025094232661865605
# intercept is 894.5188672052373

# %%
slope_14, intercept_14, r_value_14, p_value_14, std_err_14 = stats.linregress(df_14['Rate'],df_14['index1'])
print("Slope is",slope_14) 
print("intercept is" , intercept_14)
# Out:
# Slope is 0.001625337860992194
# intercept is 1168.0130428247815

# %%
slope_15, intercept_15, r_value_15, p_value_15, std_err_15 = stats.linregress(df_15['Rate'],df_15['index1'])
print("Slope is",slope_15) 
print("intercept is" , intercept_15)
# Out:
# Slope is -0.0012150858456888174
# intercept is 296.91776787186546

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_5,label='Mumbai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %% [markdown]
# ### ------------------------- xxxxxxxxxxxxxxxxxxx ----------------------------- xxxxxxxxxxxxxxxxxxxx ---------------------------

# %%
low = df_1.Rate.quantile(0.25)*0.3
high = df_1.Rate.quantile(0.75)*1.5

df_1 = df_1.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_2.Rate.quantile(0.25)*0.3
high = df_2.Rate.quantile(0.75)*1.5

df_2 = df_2.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_3.Rate.quantile(0.25)*0.3
high = df_3.Rate.quantile(0.75)*1.5

df_3 = df_3.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_4.Rate.quantile(0.25)*0.3
high = df_4.Rate.quantile(0.75)*1.5

df_4 = df_4.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_5.Rate.quantile(0.25)*0.3
high = df_5.Rate.quantile(0.75)*1.5

df_5 = df_5.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_5,label='Mumbai',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
low = df_6.Rate.quantile(0.25)*0.3
high = df_6.Rate.quantile(0.75)*1.5

df_6 = df_6.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_7.Rate.quantile(0.25)*0.3
high = df_7.Rate.quantile(0.75)*1.5

df_7 = df_7.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_8.Rate.quantile(0.25)*0.3
high = df_8.Rate.quantile(0.75)*1.5

df_8 = df_8.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_9.Rate.quantile(0.25)*0.3
high = df_9.Rate.quantile(0.75)*1.5

df_9 = df_9.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_10.Rate.quantile(0.25)*0.3
high = df_10.Rate.quantile(0.75)*1.5

df_10 = df_10.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_11.Rate.quantile(0.25)*0.3
high = df_11.Rate.quantile(0.75)*1.5

df_11 = df_11.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_12.Rate.quantile(0.25)*0.3
high = df_12.Rate.quantile(0.75)*1.5

df_12 = df_12.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_13.Rate.quantile(0.25)*0.3
high = df_13.Rate.quantile(0.75)*1.5

df_13 = df_13.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_14.Rate.quantile(0.25)*0.3
high = df_14.Rate.quantile(0.75)*1.5

df_14 = df_14.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
low = df_15.Rate.quantile(0.25)*0.3
high = df_15.Rate.quantile(0.75)*1.5

df_15 = df_15.query('{low}<Rate<{high}'.format(low=low,high=high))

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_5,label='Mumbai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
slope_1, intercept_1, r_value_1, p_value_1, std_err_1 = stats.linregress(df_1['Rate'],df_1['index1'])
print("Slope is",slope_1) 
print("intercept is" , intercept_1)
# Out:
# Slope is 0.1992914679237037
# intercept is 10193.234055826717

# %%
slope_2, intercept_2, r_value_2, p_value_2, std_err_2 = stats.linregress(df_2['Rate'],df_2['index1'])
print("Slope is",slope_2) 
print("intercept is" , intercept_2)
# Out:
# Slope is -0.07236183768560078
# intercept is 8371.477777696418

# %%
slope_3, intercept_3, r_value_3, p_value_3, std_err_3 = stats.linregress(df_3['Rate'],df_3['index1'])
print("Slope is",slope_3) 
print("intercept is" , intercept_3)
# Out:
# Slope is 0.0052050927935644664
# intercept is 8607.578261555067

# %%
slope_4, intercept_4, r_value_4, p_value_4, std_err_4 = stats.linregress(df_4['Rate'],df_4['index1'])
print("Slope is",slope_4) 
print("intercept is" , intercept_4)
# Out:
# Slope is 0.2579436137936033
# intercept is 9136.301835134054

# %%
slope_5, intercept_5, r_value_5, p_value_5, std_err_5 = stats.linregress(df_5['Rate'],df_5['index1'])
print("Slope is",slope_5) 
print("intercept is" , intercept_5)
# Out:
# Slope is 0.0532894882008968
# intercept is 5910.1988431747495

# %%
slope_6, intercept_6, r_value_6, p_value_6, std_err_6 = stats.linregress(df_6['Rate'],df_6['index1'])
print("Slope is",slope_6) 
print("intercept is" , intercept_6)
# Out:
# Slope is -0.031180693638444185
# intercept is 379.76328108351623

# %%
slope_7, intercept_7, r_value_7, p_value_7, std_err_7 = stats.linregress(df_7['Rate'],df_7['index1'])
print("Slope is",slope_7) 
print("intercept is" , intercept_7)
# Out:
# Slope is 0.06512280922061774
# intercept is 423.20167700090497

# %%
slope_8, intercept_8, r_value_8, p_value_8, std_err_8 = stats.linregress(df_8['Rate'],df_8['index1'])
print("Slope is",slope_8) 
print("intercept is" , intercept_8)
# Out:
# Slope is -0.0233750163086844
# intercept is 500.9260974556654

# %%
slope_9, intercept_9, r_value_9, p_value_9, std_err_9 = stats.linregress(df_9['Rate'],df_9['index1'])
print("Slope is",slope_9) 
print("intercept is" , intercept_9)
# Out:
# Slope is -0.011708438354095454
# intercept is 526.4727284060453

# %%
slope_10, intercept_10, r_value_10, p_value_10, std_err_10 = stats.linregress(df_10['Rate'],df_10['index1'])
print("Slope is",slope_10) 
print("intercept is" , intercept_10)
# Out:
# Slope is -0.03721216109993221
# intercept is 1078.4870486870445

# %%
slope_11, intercept_11, r_value_11, p_value_11, std_err_11 = stats.linregress(df_11['Rate'],df_11['index1'])
print("Slope is",slope_11) 
print("intercept is" , intercept_11)
# Out:
# Slope is -0.07256273656745628
# intercept is 768.8496018603147

# %%
slope_12, intercept_12, r_value_12, p_value_12, std_err_12 = stats.linregress(df_12['Rate'],df_12['index1'])
print("Slope is",slope_12) 
print("intercept is" , intercept_12)
# Out:
# Slope is -0.047037830350981455
# intercept is 738.867831523505

# %%
slope_13, intercept_13, r_value_13, p_value_13, std_err_13 = stats.linregress(df_13['Rate'],df_13['index1'])
print("Slope is",slope_13) 
print("intercept is" , intercept_13)
# Out:
# Slope is 0.007839129490152705
# intercept is 948.7243194213115

# %%
slope_14, intercept_14, r_value_14, p_value_14, std_err_14 = stats.linregress(df_14['Rate'],df_14['index1'])
print("Slope is",slope_14) 
print("intercept is" , intercept_14)
# Out:
# Slope is -0.018397531339373805
# intercept is 1234.5513024662223

# %%
slope_15, intercept_15, r_value_15, p_value_15, std_err_15 = stats.linregress(df_15['Rate'],df_15['index1'])
print("Slope is",slope_15) 
print("intercept is" , intercept_15)
# Out:
# Slope is -0.016636355497821678
# intercept is 391.6081358638246

# %% [markdown]
# ### ------------------------- xxxxxxxxxxxxxxxxxxx ----------------------------- xxxxxxxxxxxxxxxxxxxx ---------------------------

# %%
df_1 = df_1[df_1['BHK'] <= 4] 
df_2 = df_2[df_2['BHK'] <= 4] 
df_3 = df_3[df_3['BHK'] <= 4] 
df_4 = df_4[df_4['BHK'] <= 4] 
df_5 = df_5[df_5['BHK'] <= 4] 
df_6 = df_6[df_6['BHK'] <= 4] 
df_7 = df_7[df_7['BHK'] <= 4] 
df_8 = df_8[df_8['BHK'] <= 4] 
df_9 = df_9[df_9['BHK'] <= 4] 
df_10 = df_10[df_10['BHK'] <= 4] 
df_11 = df_11[df_11['BHK'] <= 4] 
df_12 = df_12[df_12['BHK'] <= 4] 
df_13 = df_13[df_13['BHK'] <= 4] 
df_14 = df_14[df_14['BHK'] <= 4] 
df_15 = df_15[df_15['BHK'] <= 4]

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_5,label='Mumbai',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_5,label='Mumbai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=df_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
slope_1, intercept_1, r_value_1, p_value_1, std_err_1 = stats.linregress(df_1['Rate'],df_1['index1'])
print("Slope is",slope_1) 
print("intercept is" , intercept_1)
# Out:
# Slope is 0.20080246237733654
# intercept is 10181.74538858647

# %%
slope_2, intercept_2, r_value_2, p_value_2, std_err_2 = stats.linregress(df_2['Rate'],df_2['index1'])
print("Slope is",slope_2) 
print("intercept is" , intercept_2)
# Out:
# Slope is -0.10112824333640862
# intercept is 8514.751467602284

# %%
slope_3, intercept_3, r_value_3, p_value_3, std_err_3 = stats.linregress(df_3['Rate'],df_3['index1'])
print("Slope is",slope_3) 
print("intercept is" , intercept_3)
# Out:
# Slope is 0.00033454018951011136
# intercept is 8619.770660501303

# %%
slope_4, intercept_4, r_value_4, p_value_4, std_err_4 = stats.linregress(df_4['Rate'],df_4['index1'])
print("Slope is",slope_4) 
print("intercept is" , intercept_4)
# Out:
# Slope is 0.25861235496878676
# intercept is 9133.776517016002

# %%
slope_5, intercept_5, r_value_5, p_value_5, std_err_5 = stats.linregress(df_5['Rate'],df_5['index1'])
print("Slope is",slope_5) 
print("intercept is" , intercept_5)
# Out:
# Slope is 0.053432676748522555
# intercept is 5909.744869469073

# %%
slope_6, intercept_6, r_value_6, p_value_6, std_err_6 = stats.linregress(df_6['Rate'],df_6['index1'])
print("Slope is",slope_6) 
print("intercept is" , intercept_6)
# Out:
# Slope is -0.031180693638444185
# intercept is 379.76328108351623

# %%
slope_7, intercept_7, r_value_7, p_value_7, std_err_7 = stats.linregress(df_7['Rate'],df_7['index1'])
print("Slope is",slope_7) 
print("intercept is" , intercept_7)
# Out:
# Slope is 0.06521210059585926
# intercept is 422.9891378976141

# %%
slope_8, intercept_8, r_value_8, p_value_8, std_err_8 = stats.linregress(df_8['Rate'],df_8['index1'])
print("Slope is",slope_8) 
print("intercept is" , intercept_8)
# Out:
# Slope is -0.02446574582240468
# intercept is 505.22484985068377

# %%
slope_9, intercept_9, r_value_9, p_value_9, std_err_9 = stats.linregress(df_9['Rate'],df_9['index1'])
print("Slope is",slope_9) 
print("intercept is" , intercept_9)
# Out:
# Slope is -0.013506432014465952
# intercept is 534.0908600315207

# %%
slope_10, intercept_10, r_value_10, p_value_10, std_err_10 = stats.linregress(df_10['Rate'],df_10['index1'])
print("Slope is",slope_10) 
print("intercept is" , intercept_10)
# Out:
# Slope is -0.038855766265810526
# intercept is 1082.7512660052114

# %%
slope_11, intercept_11, r_value_11, p_value_11, std_err_11 = stats.linregress(df_11['Rate'],df_11['index1'])
print("Slope is",slope_11) 
print("intercept is" , intercept_11)
# Out:
# Slope is -0.07156841721968145
# intercept is 766.8779538492853

# %%
slope_12, intercept_12, r_value_12, p_value_12, std_err_12 = stats.linregress(df_12['Rate'],df_12['index1'])
print("Slope is",slope_12) 
print("intercept is" , intercept_12)
# Out:
# Slope is -0.046822552115408034
# intercept is 738.4321921665384

# %%
slope_13, intercept_13, r_value_13, p_value_13, std_err_13 = stats.linregress(df_13['Rate'],df_13['index1'])
print("Slope is",slope_13) 
print("intercept is" , intercept_13)
# Out:
# Slope is 0.0050278554635831705
# intercept is 956.7570146276221

# %%
slope_14, intercept_14, r_value_14, p_value_14, std_err_14 = stats.linregress(df_14['Rate'],df_14['index1'])
print("Slope is",slope_14) 
print("intercept is" , intercept_14)
# Out:
# Slope is -0.016180292559585897
# intercept is 1225.6512906654284

# %%
slope_15, intercept_15, r_value_15, p_value_15, std_err_15 = stats.linregress(df_15['Rate'],df_15['index1'])
print("Slope is",slope_15) 
print("intercept is" , intercept_15)
# Out:
# Slope is -0.017512326023454466
# intercept is 396.1567753181277

# %% [markdown]
# ### ------------------------- xxxxxxxxxxxxxxxxxxx ----------------------------- xxxxxxxxxxxxxxxxxxxx ---------------------------

# %%
pre_covid_1 = df_1[df_1['posted_date'] <= '2020-03-01']
print (pre_covid_1.shape)

post_covid_1 = df_1[df_1['posted_date'] >= '2020-09-01']
print (post_covid_1.shape)

during_covid_1 = df_1[(df_1['posted_date'] >= '2020-04-01') & (df_1['posted_date'] <= '2020-08-01')]
print (during_covid_1.shape)
# Out:
# (4316, 23)
# (11437, 23)
# (5567, 23)

# %%
pre_covid_2 = df_2[df_2['posted_date'] <= '2020-03-01']
print (pre_covid_2.shape)

post_covid_2 = df_2[df_2['posted_date'] >= '2020-09-01']
print (post_covid_2.shape)

during_covid_2 = df_2[(df_2['posted_date'] >= '2020-04-01') & (df_2['posted_date'] <= '2020-08-01')]
print (during_covid_2.shape)
# Out:
# (2559, 23)
# (8779, 23)
# (3171, 23)

# %%
pre_covid_3 = df_3[df_3['posted_date'] <= '2020-03-01']
print (pre_covid_1.shape)

post_covid_3 = df_3[df_3['posted_date'] >= '2020-09-01']
print (post_covid_3.shape)

during_covid_3 = df_3[(df_3['posted_date'] >= '2020-04-01') & (df_3['posted_date'] <= '2020-08-01')]
print (during_covid_3.shape)
# Out:
# (4316, 23)
# (7155, 23)
# (4173, 23)

# %%
pre_covid_4 = df_4[df_4['posted_date'] <= '2020-03-01']
print (pre_covid_4.shape)

post_covid_4 = df_4[df_4['posted_date'] >= '2020-09-01']
print (post_covid_4.shape)

during_covid_4 = df_4[(df_4['posted_date'] >= '2020-04-01') & (df_4['posted_date'] <= '2020-08-01')]
print (during_covid_4.shape)
# Out:
# (5824, 23)
# (7612, 23)
# (6180, 23)

# %%
pre_covid_5 = df_5[df_5['posted_date'] <= '2020-03-01']
print (pre_covid_5.shape)

post_covid_5 = df_5[df_5['posted_date'] >= '2020-09-01']
print (post_covid_5.shape)

during_covid_5 = df_5[(df_5['posted_date'] >= '2020-04-01') & (df_5['posted_date'] <= '2020-08-01')]
print (during_covid_5.shape)
# Out:
# (556, 23)
# (9703, 23)
# (1290, 23)

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_5,label='Mumbai',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_5,label='Mumbai',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_1,label='Bengaluru',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_2,label='Chennai',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_3,label='Delhi',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_4,label='Kolkata',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_5,label='Mumbai',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
slope_1, intercept_1, r_value_1, p_value_1, std_err_1 = stats.linregress(pre_covid_1['Rate'],pre_covid_1['index1'])
print("Slope is",slope_1) 
print("intercept is" , intercept_1)
# Out:
# Slope is -0.43717455118491244
# intercept is 17814.812335912036

# %%
slope_1, intercept_1, r_value_1, p_value_1, std_err_1 = stats.linregress(during_covid_1['Rate'],during_covid_1['index1'])
print("Slope is",slope_1) 
print("intercept is" , intercept_1)
# Out:
# Slope is 0.513131628713743
# intercept is 10876.080199638916

# %%
slope_1, intercept_1, r_value_1, p_value_1, std_err_1 = stats.linregress(post_covid_1['Rate'],post_covid_1['index1'])
print("Slope is",slope_1) 
print("intercept is" , intercept_1)
# Out:
# Slope is 0.6199222084286715
# intercept is 4907.562046323377

# %%
slope_2, intercept_2, r_value_2, p_value_2, std_err_2 = stats.linregress(pre_covid_2['Rate'],pre_covid_2['index1'])
print("Slope is",slope_2) 
print("intercept is" , intercept_2)
# Out:
# Slope is -0.06700596441053186
# intercept is 9895.53663261333

# %%
slope_2, intercept_2, r_value_2, p_value_2, std_err_2 = stats.linregress(during_covid_2['Rate'],during_covid_2['index1'])
print("Slope is",slope_2) 
print("intercept is" , intercept_2)
# Out:
# Slope is 0.03083755549161552
# intercept is 9156.302027452637

# %%
slope_2, intercept_2, r_value_2, p_value_2, std_err_2 = stats.linregress(post_covid_2['Rate'],post_covid_2['index1'])
print("Slope is",slope_2) 
print("intercept is" , intercept_2)
# Out:
# Slope is -0.19608126821768235
# intercept is 8080.756280839107

# %%
slope_3, intercept_3, r_value_3, p_value_3, std_err_3 = stats.linregress(pre_covid_3['Rate'],pre_covid_3['index1'])
print("Slope is",slope_3) 
print("intercept is" , intercept_3)
# Out:
# Slope is 0.06359943504546894
# intercept is 11819.116878726141

# %%
slope_3, intercept_3, r_value_3, p_value_3, std_err_3 = stats.linregress(during_covid_3['Rate'],during_covid_3['index1'])
print("Slope is",slope_3) 
print("intercept is" , intercept_3)
# Out:
# Slope is -0.014346108273771363
# intercept is 9183.48887576754

# %%
slope_3, intercept_3, r_value_3, p_value_3, std_err_3 = stats.linregress(post_covid_3['Rate'],post_covid_3['index1'])
print("Slope is",slope_3) 
print("intercept is" , intercept_3)
# Out:
# Slope is -0.03294296704538346
# intercept is 6110.003189481097

# %%
slope_4, intercept_4, r_value_4, p_value_4, std_err_4 = stats.linregress(pre_covid_4['Rate'],pre_covid_4['index1'])
print("Slope is",slope_4) 
print("intercept is" , intercept_4)
# Out:
# Slope is -0.2103760334007277
# intercept is 15391.344206512542

# %%
slope_4, intercept_4, r_value_4, p_value_4, std_err_4 = stats.linregress(during_covid_4['Rate'],during_covid_4['index1'])
print("Slope is",slope_4) 
print("intercept is" , intercept_4)
# Out:
# Slope is 0.21987274389234984
# intercept is 10701.85879593976

# %%
slope_4, intercept_4, r_value_4, p_value_4, std_err_4 = stats.linregress(post_covid_4['Rate'],post_covid_4['index1'])
print("Slope is",slope_4) 
print("intercept is" , intercept_4)
# Out:
# Slope is 0.1518221080678277
# intercept is 5564.250728934481

# %%
slope_5, intercept_5, r_value_5, p_value_5, std_err_5 = stats.linregress(pre_covid_5['Rate'],pre_covid_5['index1'])
print("Slope is",slope_5) 
print("intercept is" , intercept_5)
# Out:
# Slope is 0.1098131113734358
# intercept is 6102.043035604538

# %%
slope_5, intercept_5, r_value_5, p_value_5, std_err_5 = stats.linregress(during_covid_5['Rate'],during_covid_5['index1'])
print("Slope is",slope_5) 
print("intercept is" , intercept_5)
# Out:
# Slope is 0.05182607997938381
# intercept is 6831.51411303188

# %%
slope_5, intercept_5, r_value_5, p_value_5, std_err_5 = stats.linregress(post_covid_5['Rate'],post_covid_5['index1'])
print("Slope is",slope_5) 
print("intercept is" , intercept_5)
# Out:
# Slope is 0.05180656361303796
# intercept is 5758.498443135588

# %%
pre_covid_6 = df_6[df_6['posted_date'] <= '2020-03-01']
print (pre_covid_6.shape)

post_covid_6 = df_6[df_6['posted_date'] >= '2020-09-01']
print (post_covid_6.shape)

during_covid_6 = df_6[(df_6['posted_date'] >= '2020-04-01') & (df_6['posted_date'] <= '2020-08-01')]
print (during_covid_6.shape)
# Out:
# (101, 23)
# (114, 23)
# (306, 23)

# %%
pre_covid_7 = df_7[df_7['posted_date'] <= '2020-03-01']
print (pre_covid_7.shape)

post_covid_7 = df_7[df_7['posted_date'] >= '2020-09-01']
print (post_covid_7.shape)

during_covid_7 = df_7[(df_7['posted_date'] >= '2020-04-01') & (df_7['posted_date'] <= '2020-08-01')]
print (during_covid_7.shape)
# Out:
# (402, 23)
# (507, 23)
# (263, 23)

# %%
pre_covid_8 = df_8[df_8['posted_date'] <= '2020-03-01']
print (pre_covid_8.shape)

post_covid_8 = df_8[df_8['posted_date'] >= '2020-09-01']
print (post_covid_8.shape)

during_covid_8 = df_8[(df_8['posted_date'] >= '2020-04-01') & (df_8['posted_date'] <= '2020-08-01')]
print (during_covid_8.shape)
# Out:
# (349, 23)
# (289, 23)
# (171, 23)

# %%
pre_covid_9 = df_9[df_9['posted_date'] <= '2020-03-01']
print (pre_covid_9.shape)

post_covid_9 = df_9[df_9['posted_date'] >= '2020-09-01']
print (post_covid_9.shape)

during_covid_9 = df_9[(df_9['posted_date'] >= '2020-04-01') & (df_9['posted_date'] <= '2020-08-01')]
print (during_covid_9.shape)
# Out:
# (610, 23)
# (175, 23)
# (116, 23)

# %%
pre_covid_10 = df_10[df_10['posted_date'] <= '2020-03-01']
print (pre_covid_10.shape)

post_covid_10 = df_10[df_10['posted_date'] >= '2020-09-01']
print (post_covid_10.shape)

during_covid_10 = df_10[(df_10['posted_date'] >= '2020-04-01') & (df_10['posted_date'] <= '2020-08-01')]
print (during_covid_10.shape)
# Out:
# (942, 23)
# (672, 23)
# (217, 23)

# %%
pre_covid_11 = df_11[df_11['posted_date'] <= '2020-03-01']
print (pre_covid_11.shape)

post_covid_11 = df_11[df_11['posted_date'] >= '2020-09-01']
print (post_covid_11.shape)

during_covid_11 = df_11[(df_11['posted_date'] >= '2020-04-01') & (df_11['posted_date'] <= '2020-08-01')]
print (during_covid_11.shape)
# Out:
# (528, 23)
# (364, 23)
# (211, 23)

# %%
pre_covid_12 = df_12[df_12['posted_date'] <= '2020-03-01']
print (pre_covid_12.shape)

post_covid_12 = df_12[df_12['posted_date'] >= '2020-09-01']
print (post_covid_12.shape)

during_covid_12 = df_12[(df_12['posted_date'] >= '2020-04-01') & (df_12['posted_date'] <= '2020-08-01')]
print (during_covid_12.shape)
# Out:
# (104, 23)
# (670, 23)
# (319, 23)

# %%
pre_covid_13 = df_13[df_13['posted_date'] <= '2020-03-01']
print (pre_covid_13.shape)

post_covid_13 = df_13[df_13['posted_date'] >= '2020-09-01']
print (post_covid_13.shape)

during_covid_13 = df_13[(df_13['posted_date'] >= '2020-04-01') & (df_13['posted_date'] <= '2020-08-01')]
print (during_covid_13.shape)
# Out:
# (605, 23)
# (766, 23)
# (499, 23)

# %%
pre_covid_14 = df_14[df_14['posted_date'] <= '2020-03-01']
print (pre_covid_14.shape)

post_covid_14 = df_14[df_14['posted_date'] >= '2020-09-01']
print (post_covid_14.shape)

during_covid_14 = df_14[(df_14['posted_date'] >= '2020-04-01') & (df_14['posted_date'] <= '2020-08-01')]
print (during_covid_14.shape)
# Out:
# (870, 23)
# (719, 23)
# (619, 23)

# %%
pre_covid_15 = df_15[df_15['posted_date'] <= '2020-03-01']
print (pre_covid_15.shape)

post_covid_15 = df_15[df_15['posted_date'] >= '2020-09-01']
print (post_covid_15.shape)

during_covid_15 = df_15[(df_15['posted_date'] >= '2020-04-01') & (df_15['posted_date'] <= '2020-08-01')]
print (during_covid_15.shape)
# Out:
# (202, 23)
# (183, 23)
# (129, 23)

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=pre_covid_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
slope_6, intercept_6, r_value_6, p_value_6, std_err_6 = stats.linregress(pre_covid_6['Rate'],pre_covid_6['index1'])
print("Slope is",slope_6) 
print("intercept is" , intercept_6)
# Out:
# Slope is -0.03053200465991222
# intercept is 382.7108652255346

# %%
slope_6, intercept_6, r_value_6, p_value_6, std_err_6 = stats.linregress(during_covid_6['Rate'],during_covid_6['index1'])
print("Slope is",slope_6) 
print("intercept is" , intercept_6)
# Out:
# Slope is -0.02421888720246331
# intercept is 363.82437508913813

# %%
slope_6, intercept_6, r_value_6, p_value_6, std_err_6 = stats.linregress(post_covid_6['Rate'],post_covid_6['index1'])
print("Slope is",slope_6) 
print("intercept is" , intercept_6)
# Out:
# Slope is -0.048403079446407385
# intercept is 409.5099873183864

# %%
slope_7, intercept_7, r_value_7, p_value_7, std_err_7 = stats.linregress(pre_covid_7['Rate'],pre_covid_7['index1'])
print("Slope is",slope_7) 
print("intercept is" , intercept_7)
# Out:
# Slope is 0.10148889817884944
# intercept is 247.69675796050274

# %%
slope_7, intercept_7, r_value_7, p_value_7, std_err_7 = stats.linregress(during_covid_7['Rate'],during_covid_7['index1'])
print("Slope is",slope_7) 
print("intercept is" , intercept_7)
# Out:
# Slope is 0.03583978215704272
# intercept is 740.2037740248309

# %%
slope_7, intercept_7, r_value_7, p_value_7, std_err_7 = stats.linregress(post_covid_7['Rate'],post_covid_7['index1'])
print("Slope is",slope_7) 
print("intercept is" , intercept_7)
# Out:
# Slope is 0.0909898683651475
# intercept is 292.39818513684963

# %%
slope_8, intercept_8, r_value_8, p_value_8, std_err_8 = stats.linregress(pre_covid_8['Rate'],pre_covid_8['index1'])
print("Slope is",slope_8) 
print("intercept is" , intercept_8)
# Out:
# Slope is -0.010897001221159804
# intercept is 447.9399085578508

# %%
slope_8, intercept_8, r_value_8, p_value_8, std_err_8 = stats.linregress(during_covid_8['Rate'],during_covid_8['index1'])
print("Slope is",slope_8) 
print("intercept is" , intercept_8)
# Out:
# Slope is -0.019307601069546893
# intercept is 531.9445778738573

# %%
slope_8, intercept_8, r_value_8, p_value_8, std_err_8 = stats.linregress(post_covid_8['Rate'],post_covid_8['index1'])
print("Slope is",slope_8) 
print("intercept is" , intercept_8)
# Out:
# Slope is -0.040299506170358476
# intercept is 551.2346374634362

# %%
slope_9, intercept_9, r_value_9, p_value_9, std_err_9 = stats.linregress(pre_covid_9['Rate'],pre_covid_9['index1'])
print("Slope is",slope_9) 
print("intercept is" , intercept_9)
# Out:
# Slope is -0.01036537808158438
# intercept is 588.4383622334777

# %%
slope_9, intercept_9, r_value_9, p_value_9, std_err_9 = stats.linregress(during_covid_9['Rate'],during_covid_9['index1'])
print("Slope is",slope_9) 
print("intercept is" , intercept_9)
# Out:
# Slope is -0.014082993901052181
# intercept is 481.8709820809325

# %%
slope_9, intercept_9, r_value_9, p_value_9, std_err_9 = stats.linregress(post_covid_9['Rate'],post_covid_9['index1'])
print("Slope is",slope_9) 
print("intercept is" , intercept_9)
# Out:
# Slope is -0.03719448061099069
# intercept is 430.12341467398124

# %%
slope_10, intercept_10, r_value_10, p_value_10, std_err_10 = stats.linregress(pre_covid_10['Rate'],pre_covid_10['index1'])
print("Slope is",slope_10) 
print("intercept is" , intercept_10)
# Out:
# Slope is 0.03554091422465959
# intercept is 952.8693726018473

# %%
slope_10, intercept_10, r_value_10, p_value_10, std_err_10 = stats.linregress(during_covid_10['Rate'],during_covid_10['index1'])
print("Slope is",slope_10) 
print("intercept is" , intercept_10)
# Out:
# Slope is -0.06100639795003491
# intercept is 948.9427613728959

# %%
slope_10, intercept_10, r_value_10, p_value_10, std_err_10 = stats.linregress(post_covid_10['Rate'],post_covid_10['index1'])
print("Slope is",slope_10) 
print("intercept is" , intercept_10)
# Out:
# Slope is -0.1496633849307949
# intercept is 1366.2718903253717

# %%
slope_11, intercept_11, r_value_11, p_value_11, std_err_11 = stats.linregress(pre_covid_11['Rate'],pre_covid_11['index1'])
print("Slope is",slope_11) 
print("intercept is" , intercept_11)
# Out:
# Slope is 0.02421764741750997
# intercept is 403.8787252111164

# %%
slope_11, intercept_11, r_value_11, p_value_11, std_err_11 = stats.linregress(during_covid_11['Rate'],during_covid_11['index1'])
print("Slope is",slope_11) 
print("intercept is" , intercept_11)
# Out:
# Slope is 0.05515690562317352
# intercept is 705.1918192329832

# %%
slope_11, intercept_11, r_value_11, p_value_11, std_err_11 = stats.linregress(post_covid_11['Rate'],post_covid_11['index1'])
print("Slope is",slope_11) 
print("intercept is" , intercept_11)
# Out:
# Slope is -0.19370126250024633
# intercept is 1044.642024063654

# %%
slope_12, intercept_12, r_value_12, p_value_12, std_err_12 = stats.linregress(pre_covid_12['Rate'],pre_covid_12['index1'])
print("Slope is",slope_12) 
print("intercept is" , intercept_12)
# Out:
# Slope is -0.009607366027050193
# intercept is 470.4177263241881

# %%
slope_12, intercept_12, r_value_12, p_value_12, std_err_12 = stats.linregress(during_covid_12['Rate'],during_covid_12['index1'])
print("Slope is",slope_12) 
print("intercept is" , intercept_12)
# Out:
# Slope is -0.04504284601781445
# intercept is 947.63741578809

# %%
slope_12, intercept_12, r_value_12, p_value_12, std_err_12 = stats.linregress(post_covid_12['Rate'],post_covid_12['index1'])
print("Slope is",slope_12) 
print("intercept is" , intercept_12)
# Out:
# Slope is -0.01799798089934545
# intercept is 554.1675628645297

# %%
slope_13, intercept_13, r_value_13, p_value_13, std_err_13 = stats.linregress(pre_covid_13['Rate'],pre_covid_13['index1'])
print("Slope is",slope_13) 
print("intercept is" , intercept_13)
# Out:
# Slope is -0.02696671390151846
# intercept is 1044.7275887365508

# %%
slope_13, intercept_13, r_value_13, p_value_13, std_err_13 = stats.linregress(during_covid_13['Rate'],during_covid_13['index1'])
print("Slope is",slope_13) 
print("intercept is" , intercept_13)
# Out:
# Slope is -0.02032399664843026
# intercept is 1299.237407897997

# %%
slope_13, intercept_13, r_value_13, p_value_13, std_err_13 = stats.linregress(post_covid_13['Rate'],post_covid_13['index1'])
print("Slope is",slope_13) 
print("intercept is" , intercept_13)
# Out:
# Slope is -0.01236232360258185
# intercept is 863.9062379893485

# %%
slope_14, intercept_14, r_value_14, p_value_14, std_err_14 = stats.linregress(pre_covid_4['Rate'],pre_covid_4['index1'])
print("Slope is",slope_14) 
print("intercept is" , intercept_14)
# Out:
# Slope is -0.2103760334007277
# intercept is 15391.344206512542

# %%
slope_14, intercept_14, r_value_14, p_value_14, std_err_14 = stats.linregress(during_covid_14['Rate'],during_covid_14['index1'])
print("Slope is",slope_14) 
print("intercept is" , intercept_14)
# Out:
# Slope is 0.17425241144865034
# intercept is 1010.3265559880997

# %%
slope_14, intercept_14, r_value_14, p_value_14, std_err_14 = stats.linregress(post_covid_14['Rate'],post_covid_14['index1'])
print("Slope is",slope_14) 
print("intercept is" , intercept_14)
# Out:
# Slope is -0.08427739376828122
# intercept is 1641.7467111417564

# %%
slope_15, intercept_15, r_value_15, p_value_15, std_err_15 = stats.linregress(pre_covid_15['Rate'],pre_covid_15['index1'])
print("Slope is",slope_15) 
print("intercept is" , intercept_15)
# Out:
# Slope is -0.009409801990254001
# intercept is 335.51203934065006

# %%
slope_15, intercept_15, r_value_15, p_value_15, std_err_15 = stats.linregress(during_covid_15['Rate'],during_covid_15['index1'])
print("Slope is",slope_15) 
print("intercept is" , intercept_15)
# Out:
# Slope is -0.032466977358468076
# intercept is 518.431426829627

# %%
slope_15, intercept_15, r_value_15, p_value_15, std_err_15 = stats.linregress(post_covid_15['Rate'],post_covid_15['index1'])
print("Slope is",slope_15) 
print("intercept is" , intercept_15)
# Out:
# Slope is -0.01622303560322084
# intercept is 369.63268514104413

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=during_covid_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %%
fig_dims = (20, 10)
fig, ax = plt.subplots(figsize=fig_dims)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_6,label='Nashik',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_7,label='Raipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_8,label='Bhubaneswar',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_9,label='lucknow',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_10,label='Jaipur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_11,label='Indore',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_12,label='Kanpur',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_13,label='Surat',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_14,label='Visakhapatnam',linewidth=5)
sns.lineplot(x='posted_date', y='Rate', ax=ax, data=post_covid_15,label='Goa',linewidth=5)
ax.set_xlabel('posted_date')
ax.set_ylabel('Rate')
#ax.set_title('Lucknow_&_Bangalore')
plt.legend()
plt.show()

# %% [markdown]
# ### ------------------------- xxxxxxxxxxxxxxxxxxx ----------------------------- xxxxxxxxxxxxxxxxxxxx ---------------------------

# %%
pre_covid_1.head(5)
# Out:
#         Power Backup           Lift 24 X 7 Security Children's play area  \
# 20331  Not Available  Not Available       Available            Available
# 3640       Available      Available   Not Available        Not Available
# 3641       Available      Available   Not Available            Available
# 21686      Available      Available       Available            Available
# 21697      Available      Available       Available            Available
#
#        Gymnasium Landscaped Gardens    Car Parking     Club House  \
# 20331  Available          Available      Available      Available
# 3640   Available      Not Available      Available  Not Available
# 3641   Available      Not Available  Not Available  Not Available
# 21686  Available          Available      Available      Available
# 21697  Available          Available      Available      Available
#
#                    Status  Bathrooms  ... Balconies Price Negotiable  \
# ...

# %%
sns.displot(df_1['Rate'],kind="kde")
sns.displot(df_2['Rate'],kind="kde")
sns.displot(df_3['Rate'],kind="kde")
sns.displot(df_4['Rate'],kind="kde")
sns.displot(df_5['Rate'],kind="kde")

# %%
# Create an array with the colors you want to use
sns.set_theme(style="darkgrid")
sns.displot(df_1, x="Rate",hue='BHK',kde=True,palette='nipy_spectral')

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 21320 entries, 20331 to 0
# Data columns (total 23 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Power Backup          21320 non-null  object
#  1   Lift                  21320 non-null  object
#  2   24 X 7 Security       21320 non-null  object
#  3   Children's play area  21320 non-null  object
#  4   Gymnasium             21320 non-null  object
#  5   Landscaped Gardens    21320 non-null  object
#  6   Car Parking           21320 non-null  object
#  7   Club House            21320 non-null  object
#  8   Status                21320 non-null  object
#  9   Bathrooms             12225 non-null  float64
#  10  Floor                 4245 non-null   object
#  11  New/Resale            17492 non-null  object
#  12  Additional Rooms      16 non-null     object
#  13  Balconies             40 non-null     float64
#  14  Price Negotiable      5995 non-null   object
# ...

# %%
sns.set_theme(style="darkgrid")

ax = sns.countplot(x="BHK", data=df_1)

# %%
sns.pairplot(df_1,hue='BHK',palette='tab20')

# %%
sns.pairplot(df_6,hue='BHK',palette='tab20c_r')

# %%
df_6 = df_6.sort_values(by=['posted_date'])

# %%
df_6.plot(x='posted_date',y='Rate')

# %%
ax = df_1.plot(x ='posted_date' ,y='Rate')
df_6.plot(x='posted_date', y='Rate',color='Red',ax=ax)

# %%
import plotly.express as px
from scipy import stats

fig = px.scatter(df_6, x="Area", y="Rate", trendline="ols")
fig.show()

# %%
from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(df_6['Rate'],df_6['index1'])

# %%
df_6['index1'] = df_6.index

# %%
slope

# %%
intercept

# %%
r_value

# %%
p_value

# %%
std_err

# %%
df_6 = df_6.sort_values(by=['posted_date'])
df_6['index1'] = df_6.index


from scipy import stats

slope, intercept, r_value, p_value, std_err = stats.linregress(df_6['Rate'],df_6['index1'])

# %%
import warnings
warnings.simplefilter('ignore')

import matplotlib.pyplot as plt
import seaborn as sns

import numpy as np
import pandas as pd

# %%
df = pd.read_csv('makaan_gawahati_n.csv')

# %%
df.head(30)
# Out:
#                                                   Url  \
# 0   https://www.makaan.com/guwahati/builder-projec...
# 1   https://www.makaan.com/guwahati/evolution-cons...
# 2   https://www.makaan.com/guwahati/saroj-parkland...
# 3   https://www.makaan.com/guwahati/htn-developers...
# 4   https://www.makaan.com/guwahati/htn-developers...
# 5   https://www.makaan.com/guwahati/htn-developers...
# 6   https://www.makaan.com/guwahati/evolution-cons...
# 7   https://www.makaan.com/guwahati/builder-rajdha...
# 8   https://www.makaan.com/guwahati/saroj-parkland...
# 9   https://www.makaan.com/guwahati/builder-projec...
# 10  https://www.makaan.com/guwahati/builder-projec...
# 11  https://www.makaan.com/guwahati/builder-projec...
# 12  https://www.makaan.com/guwahati/builder-projec...
# 13  https://www.makaan.com/guwahati/builder-citize...
# 14  https://www.makaan.com/guwahati/builder-projec...
# 15  https://www.makaan.com/guwahati/htn-developers...
# ...

# %%
df.drop(['Url'], axis=1,inplace=True)
df.head()
# Out:
#                                                 Name      price  \
# 0  1260 sq ft 3 BHK 2T NorthEast facing Apartment...   44.1LEMI
# 1  950 sq ft 2 BHK Apartment for sale at Rs 40.85...  40.85LEMI
# 2  1630 sq ft 3 BHK 3T Apartment for sale at Rs 6...     62LEMI
# 3  1045 sq ft 2 BHK Apartment for sale at Rs 43.8...  43.89LEMI
# 4  1375 sq ft 3 BHK Under Construction property A...  57.75LEMI
#
#             posteddate                                                bhk  \
# 0  Posted 16 hours ago  3 BHK Apartment - 1,260 sq ft\nBhetapara, Guwa...
# 1  Posted 2 months ago  2 BHK Apartment - 950 sq ft\nEvolution Chitra ...
# 2   Posted a month ago  3 BHK Apartment - 1,630 sq ft\nSaroj ParklandB...
# 3    Posted 7 days ago  2 BHK Apartment - 1,045 sq ft\nHTN Om PlazaKah...
# 4    Posted 7 days ago  3 BHK Apartment - 1,375 sq ft\nHTN Om PlazaKah...
#
#                                             features            rate  \
# ...

# %%
df.shape
# Out:
# (229, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 229 entries, 0 to 228
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        229 non-null    object
#  1   price       229 non-null    object
#  2   posteddate  229 non-null    object
#  3   bhk         229 non-null    object
#  4   features    229 non-null    object
#  5   rate        229 non-null    object
#  6   amenities   229 non-null    object
# dtypes: object(7)
# memory usage: 12.6+ KB

# %%
df.drop_duplicates(inplace=True)
df.head()
# Out:
#                                                 Name      price  \
# 0  1260 sq ft 3 BHK 2T NorthEast facing Apartment...   44.1LEMI
# 1  950 sq ft 2 BHK Apartment for sale at Rs 40.85...  40.85LEMI
# 2  1630 sq ft 3 BHK 3T Apartment for sale at Rs 6...     62LEMI
# 3  1045 sq ft 2 BHK Apartment for sale at Rs 43.8...  43.89LEMI
# 4  1375 sq ft 3 BHK Under Construction property A...  57.75LEMI
#
#             posteddate                                                bhk  \
# 0  Posted 16 hours ago  3 BHK Apartment - 1,260 sq ft\nBhetapara, Guwa...
# 1  Posted 2 months ago  2 BHK Apartment - 950 sq ft\nEvolution Chitra ...
# 2   Posted a month ago  3 BHK Apartment - 1,630 sq ft\nSaroj ParklandB...
# 3    Posted 7 days ago  2 BHK Apartment - 1,045 sq ft\nHTN Om PlazaKah...
# 4    Posted 7 days ago  3 BHK Apartment - 1,375 sq ft\nHTN Om PlazaKah...
#
#                                             features            rate  \
# ...

# %%
df.shape
# Out:
# (228, 7)

# %%
missing = np.where(df['price'].isnull()==True)
missing
# Out:
# (array([], dtype=int64),)

# %%
missing1 = np.where(df['rate'].isnull()==True)
missing1
# Out:
# (array([], dtype=int64),)

# %%
missing2 = np.where(df['bhk'].isnull()==True)
missing2
# Out:
# (array([], dtype=int64),)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 228 entries, 0 to 228
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        228 non-null    object
#  1   price       228 non-null    object
#  2   posteddate  228 non-null    object
#  3   bhk         228 non-null    object
#  4   features    228 non-null    object
#  5   rate        228 non-null    object
#  6   amenities   228 non-null    object
# dtypes: object(7)
# memory usage: 14.2+ KB

# %%
df.head(10)
# Out:
#                                                 Name             price  \
# 0  1260 sq ft 3 BHK 2T NorthEast facing Apartment...          44.1LEMI
# 1  950 sq ft 2 BHK Apartment for sale at Rs 40.85...         40.85LEMI
# 2  1630 sq ft 3 BHK 3T Apartment for sale at Rs 6...            62LEMI
# 3  1045 sq ft 2 BHK Apartment for sale at Rs 43.8...         43.89LEMI
# 4  1375 sq ft 3 BHK Under Construction property A...         57.75LEMI
# 5  1011 sq ft 2 BHK Under Construction property A...         42.46LEMI
# 6  1170 sq ft 3 BHK Under Construction property A...         50.31LEMI
# 7  1400 sq ft 3 BHK 2T NorthWest facing Apartment...  58LEMINegotiable
# 8  1910 sq ft 3 BHK 3T SouthWest facing Apartment...         69.85LEMI
# 9  1600 sq ft 3 BHK 2T NorthEast facing Apartment...  72LEMINegotiable
#
#              posteddate                                                bhk  \
# 0   Posted 16 hours ago  3 BHK Apartment - 1,260 sq ft\nBhetapara, Guwa...
# ...

# %%
df[['price','EMI']] = df.price.str.split("L", expand=True)

# %%
df.head()
# Out:
#                                                 Name  price  \
# 0  1260 sq ft 3 BHK 2T NorthEast facing Apartment...   44.1
# 1  950 sq ft 2 BHK Apartment for sale at Rs 40.85...  40.85
# 2  1630 sq ft 3 BHK 3T Apartment for sale at Rs 6...     62
# 3  1045 sq ft 2 BHK Apartment for sale at Rs 43.8...  43.89
# 4  1375 sq ft 3 BHK Under Construction property A...  57.75
#
#             posteddate                                                bhk  \
# 0  Posted 16 hours ago  3 BHK Apartment - 1,260 sq ft\nBhetapara, Guwa...
# 1  Posted 2 months ago  2 BHK Apartment - 950 sq ft\nEvolution Chitra ...
# 2   Posted a month ago  3 BHK Apartment - 1,630 sq ft\nSaroj ParklandB...
# 3    Posted 7 days ago  2 BHK Apartment - 1,045 sq ft\nHTN Om PlazaKah...
# 4    Posted 7 days ago  3 BHK Apartment - 1,375 sq ft\nHTN Om PlazaKah...
#
#                                             features            rate  \
# 0  Status\nReady to move\nBathrooms\n2\nNew/Resal...   3,500/ sq ft
# ...

# %%
df.price.value_counts()
# Out:
# 45       12
# 40        8
# 55        8
# 75        7
# 50        7
#          ..
# 41.99     1
# 38.02     1
# 67.5      1
# 49.89     1
# 71.14     1
# Name: price, Length: 123, dtype: int64

# %%
df[['BHK','NEW']] = df.bhk.str.split(" - ", expand=True)

# %%
df.head(10)
# Out:
#                                                 Name  price  \
# 0  1260 sq ft 3 BHK 2T NorthEast facing Apartment...   44.1
# 1  950 sq ft 2 BHK Apartment for sale at Rs 40.85...  40.85
# 2  1630 sq ft 3 BHK 3T Apartment for sale at Rs 6...     62
# 3  1045 sq ft 2 BHK Apartment for sale at Rs 43.8...  43.89
# 4  1375 sq ft 3 BHK Under Construction property A...  57.75
# 5  1011 sq ft 2 BHK Under Construction property A...  42.46
# 6  1170 sq ft 3 BHK Under Construction property A...  50.31
# 7  1400 sq ft 3 BHK 2T NorthWest facing Apartment...     58
# 8  1910 sq ft 3 BHK 3T SouthWest facing Apartment...  69.85
# 9  1600 sq ft 3 BHK 2T NorthEast facing Apartment...     72
#
#              posteddate                                                bhk  \
# 0   Posted 16 hours ago  3 BHK Apartment - 1,260 sq ft\nBhetapara, Guwa...
# 1   Posted 2 months ago  2 BHK Apartment - 950 sq ft\nEvolution Chitra ...
# 2    Posted a month ago  3 BHK Apartment - 1,630 sq ft\nSaroj ParklandB...
# ...

# %%
df[['sqft1','Location']] = df.NEW.str.split("\n", expand=True)

# %%
df.head(10)
# Out:
#                                                 Name  price  \
# 0  1260 sq ft 3 BHK 2T NorthEast facing Apartment...   44.1
# 1  950 sq ft 2 BHK Apartment for sale at Rs 40.85...  40.85
# 2  1630 sq ft 3 BHK 3T Apartment for sale at Rs 6...     62
# 3  1045 sq ft 2 BHK Apartment for sale at Rs 43.8...  43.89
# 4  1375 sq ft 3 BHK Under Construction property A...  57.75
# 5  1011 sq ft 2 BHK Under Construction property A...  42.46
# 6  1170 sq ft 3 BHK Under Construction property A...  50.31
# 7  1400 sq ft 3 BHK 2T NorthWest facing Apartment...     58
# 8  1910 sq ft 3 BHK 3T SouthWest facing Apartment...  69.85
# 9  1600 sq ft 3 BHK 2T NorthEast facing Apartment...     72
#
#              posteddate                                                bhk  \
# 0   Posted 16 hours ago  3 BHK Apartment - 1,260 sq ft\nBhetapara, Guwa...
# 1   Posted 2 months ago  2 BHK Apartment - 950 sq ft\nEvolution Chitra ...
# 2    Posted a month ago  3 BHK Apartment - 1,630 sq ft\nSaroj ParklandB...
# ...

# %%
df[['Location','City']] = df.Location.str.split(",", expand=True) 
df.head()
# Out:
#                                                 Name  price  \
# 0  1260 sq ft 3 BHK 2T NorthEast facing Apartment...   44.1
# 1  950 sq ft 2 BHK Apartment for sale at Rs 40.85...  40.85
# 2  1630 sq ft 3 BHK 3T Apartment for sale at Rs 6...     62
# 3  1045 sq ft 2 BHK Apartment for sale at Rs 43.8...  43.89
# 4  1375 sq ft 3 BHK Under Construction property A...  57.75
#
#             posteddate                                                bhk  \
# 0  Posted 16 hours ago  3 BHK Apartment - 1,260 sq ft\nBhetapara, Guwa...
# 1  Posted 2 months ago  2 BHK Apartment - 950 sq ft\nEvolution Chitra ...
# 2   Posted a month ago  3 BHK Apartment - 1,630 sq ft\nSaroj ParklandB...
# 3    Posted 7 days ago  2 BHK Apartment - 1,045 sq ft\nHTN Om PlazaKah...
# 4    Posted 7 days ago  3 BHK Apartment - 1,375 sq ft\nHTN Om PlazaKah...
#
#                                             features            rate  \
# 0  Status\nReady to move\nBathrooms\n2\nNew/Resal...   3,500/ sq ft
# ...

# %%
df.drop(['City', 'NEW', 'EMI','bhk','rate','Name'], axis=1, inplace=True)

# %%
df.head(10)
# Out:
#    price            posteddate  \
# 0   44.1   Posted 16 hours ago
# 1  40.85   Posted 2 months ago
# 2     62    Posted a month ago
# 3  43.89     Posted 7 days ago
# 4  57.75     Posted 7 days ago
# 5  42.46     Posted 7 days ago
# 6  50.31   Posted 2 months ago
# 7     58    Posted 11 days ago
# 8  69.85  Posted 10 months ago
# 9     72  Posted 10 months ago
#
#                                             features  \
# 0  Status\nReady to move\nBathrooms\n2\nNew/Resal...
# 1  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 2  Status\nUnder Construction\nBathrooms\n3\nNew/...
# 3  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 4  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 5  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 6  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 7  Carpet area\n1200 sq ft\nStatus\nUnder Constru...
# 8  Carpet area\n1530 sq ft\nStatus\nUnder Constru...
# 9  Status\nReady to move\nFloor\n6th of 9\nBathro...
#
# ...

# %%
df.BHK.unique()
# Out:
# array(['3 BHK Apartment', '2 BHK Apartment', '1 BHK Apartment',
#        '4 BHK Apartment', '1 RK Studio Apartment'], dtype=object)

# %%
df[['BHK','aprt']] = df.BHK.str.split("BHK", expand=True)

# %%
df.head(10)
# Out:
#    price            posteddate  \
# 0   44.1   Posted 16 hours ago
# 1  40.85   Posted 2 months ago
# 2     62    Posted a month ago
# 3  43.89     Posted 7 days ago
# 4  57.75     Posted 7 days ago
# 5  42.46     Posted 7 days ago
# 6  50.31   Posted 2 months ago
# 7     58    Posted 11 days ago
# 8  69.85  Posted 10 months ago
# 9     72  Posted 10 months ago
#
#                                             features  \
# 0  Status\nReady to move\nBathrooms\n2\nNew/Resal...
# 1  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 2  Status\nUnder Construction\nBathrooms\n3\nNew/...
# 3  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 4  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 5  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 6  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 7  Carpet area\n1200 sq ft\nStatus\nUnder Constru...
# 8  Carpet area\n1530 sq ft\nStatus\nUnder Constru...
# 9  Status\nReady to move\nFloor\n6th of 9\nBathro...
#
# ...

# %%
df.BHK.unique()
# Out:
# array(['3 ', '2 ', '1 ', '4 ', '1 RK Studio Apartment'], dtype=object)

# %%
df.BHK.value_counts()
# Out:
# 3                        137
# 2                         74
# 4                         11
# 1                          5
# 1 RK Studio Apartment      1
# Name: BHK, dtype: int64

# %%
df.drop('aprt',axis=1,inplace=True)

# %%
df.head()
# Out:
#    price           posteddate  \
# 0   44.1  Posted 16 hours ago
# 1  40.85  Posted 2 months ago
# 2     62   Posted a month ago
# 3  43.89    Posted 7 days ago
# 4  57.75    Posted 7 days ago
#
#                                             features  \
# 0  Status\nReady to move\nBathrooms\n2\nNew/Resal...
# 1  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 2  Status\nUnder Construction\nBathrooms\n3\nNew/...
# 3  Status\nUnder Construction\nNew/Resale\nNew\nP...
# 4  Status\nUnder Construction\nNew/Resale\nNew\nP...
#
#                                            amenities BHK        sqft1  \
# 0  Power Backup\nLift Available\n24 X 7 Security\...  3   1,260 sq ft
# 1  Power Backup\nLift Available\n24 X 7 Security\...  2     950 sq ft
# 2  Lift Available\nNot Available\nPower Backup\nN...  3   1,630 sq ft
# 3  Lift Available\nPower Backup\nNot Available\n2...  2   1,045 sq ft
# 4  Lift Available\nPower Backup\nNot Available\n2...  3   1,375 sq ft
#
# ...

# %%
dfn = df.copy()

# %% [markdown]
# dfn['Price'] = dfn['price'].apply(lambda x: str(re.split('(\d+)',x)[1]))
# dfn.head(30)

# %% [markdown]
# import re
# def separate_number_chars(s):
#     res = re.split('([-+]?\d+\.\d+)|([-+]?\d+)', s.strip())
#     res_f = [r.strip() for r in res if r is not None and r.strip() != '']
#     return res_f
#
# separate_number_chars('74.5LEMI')

# %% [markdown]
# dfn[['firstcol', 'secondcol']] = dfn['price'].str.extract('(\d+\.?\d*)([A-Za-z]+)', expand = True)

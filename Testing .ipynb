# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('makaan_Guwahati.csv')

# %%
df = df.dropna(thresh=3)

# %%
df['features'] = df['features'].apply(lambda x: x.split('\n'))

# %%
for i in df['features']:
    for j in i:
        if 'Carpet area' in i:
            pass
        else:
            i.append('Carpet area')
            i.append('0 sq ft')

# %%
x = []

for i in df['features']:
    item_1 = i
    
    index = item_1.index('Carpet area')
    next_index = index + 1
    x.append(next_index)

# %%
for i in df['features']:
    print(i)
# Out:
# ['Status', 'Ready to move', 'Bathrooms', '2', 'New/Resale', 'Resale', 'Carpet area', '0 sq ft']
# ['Status', 'Under Construction', 'New/Resale', 'New', 'Price Negotiable', 'No', 'Carpet area', '0 sq ft']
# ['Status', 'Under Construction', 'Bathrooms', '3', 'New/Resale', 'Resale', 'Carpet area', '0 sq ft']
# ['Status', 'Under Construction', 'New/Resale', 'New', 'Price Negotiable', 'No', 'Carpet area', '0 sq ft']
# ['Status', 'Under Construction', 'New/Resale', 'New', 'Price Negotiable', 'No', 'Carpet area', '0 sq ft']
# ['Status', 'Under Construction', 'New/Resale', 'New', 'Price Negotiable', 'No', 'Carpet area', '0 sq ft']
# ['Status', 'Under Construction', 'New/Resale', 'New', 'Price Negotiable', 'No', 'Carpet area', '0 sq ft']
# ['Carpet area', '1200 sq ft', 'Status', 'Under Construction', 'Floor', '1st of 4', 'Bathrooms', '2']
# ['Carpet area', '1530 sq ft', 'Status', 'Under Construction', 'Floor', '6th of 9', 'Bathrooms', '3']
# ...

# %%
y = []
for i in df['features']:
    for j in i:
        if 'Carpet area' in j:
            print(i[i.index(j)+1])
            y.append(i[i.index(j)+1])
# Out:
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 1200 sq ft
# 1530 sq ft
# 0 sq ft
# 950 sq ft
# 1050 sq ft
# 600 sq ft
# 0 sq ft
# 950 sq ft
# 0 sq ft
# 1350 sq ft
# 1250 sq ft
# 1001 sq ft
# 800 sq ft
# 1500 sq ft
# 0 sq ft
# 0 sq ft
# 850 sq ft
# 0 sq ft
# 990 sq ft
# 844 sq ft
# 1500 sq ft
# 1460 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 1000 sq ft
# 1080 sq ft
# 670 sq ft
# 0 sq ft
# 790 sq ft
# 960 sq ft
# 0 sq ft
# 1314 sq ft
# 1138 sq ft
# 800 sq ft
# 0 sq ft
# 1300 sq ft
# 0 sq ft
# 800 sq ft
# 0 sq ft
# 1550 sq ft
# 1150 sq ft
# 1200 sq ft
# 1050 sq ft
# 0 sq ft
# 1357 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 1304 sq ft
# 0 sq ft
# 0 sq ft
# 965 sq ft
# 1200 sq ft
# 1208 sq ft
# 880 sq ft
# 675 sq ft
# 930 sq ft
# 800 sq ft
# 0 sq ft
# 1000 sq ft
# 1085 sq ft
# 900 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 0 sq ft
# 1166 sq ft
# 1400 sq ft
# 1048 sq ft
# 750 sq ft
# 0 sq ft
# 0 sq ft
# 2150 sq ft
# 1050 sq ft
# 0 sq ft
# 1160 sq ft
# 709 sq ft
# ...

# %%
y
# Out:
# ['0 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '1200 sq ft',
#  '1530 sq ft',
#  '0 sq ft',
#  '950 sq ft',
#  '1050 sq ft',
#  '600 sq ft',
#  '0 sq ft',
#  '950 sq ft',
#  '0 sq ft',
#  '1350 sq ft',
#  '1250 sq ft',
#  '1001 sq ft',
#  '800 sq ft',
#  '1500 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '850 sq ft',
#  '0 sq ft',
#  '990 sq ft',
#  '844 sq ft',
#  '1500 sq ft',
#  '1460 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '1000 sq ft',
#  '1080 sq ft',
#  '670 sq ft',
#  '0 sq ft',
#  '790 sq ft',
#  '960 sq ft',
#  '0 sq ft',
#  '1314 sq ft',
#  '1138 sq ft',
#  '800 sq ft',
#  '0 sq ft',
#  '1300 sq ft',
#  '0 sq ft',
#  '800 sq ft',
#  '0 sq ft',
#  '1550 sq ft',
#  '1150 sq ft',
#  '1200 sq ft',
#  '1050 sq ft',
#  '0 sq ft',
#  '1357 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '1304 sq ft',
#  '0 sq ft',
#  '0 sq ft',
#  '965 sq ft',
#  '1200 sq ft',
#  '1208 sq ft',
#  '880 sq ft',
# ...

# %%
y = []
z =[] 
for i in df['features']:
    y.append(i)

# %%
np.shape(y)

# %%
y.sort(key=lambda x:x[1])

# %%
print(y)

# %%
for i in y:
    for j in i:
        print(y[i][x[j]])

# %%
y[1][7]

# %%
for i in df['features']:
    for j in i:
        if 'Carpet area' in i:
            pass
        else:
            i.append('Carpet area')
            i.append('0 sq ft')
    for ji in i:
        if 'Carpet area' in ji:
            print(i.index('Carpet area'))
            print(i,i[i.index(ji)+1])

# %%
for i in df['features']:
    print (df['features'][i][x[i-1]])
